# %% [markdown]
# # 文法についての練習

# %% [markdown]
# ## リテラル

# %%
num = 100
str = "spam"
bool = True

print(num)
print(str)
print(bool)
# Out:
# 100
# spam
# True

# %%
print(num * 10)
# Out:
# 1000

# %%
print(str[0])
print(str[0:2])
# Out:
# s
# sp

# %% [markdown]
# ## if文

# %%
if bool:
    print('True!!')
else:
    print('False!!')
# Out:
# True!!

# %%
if num > 0:
    print('0以上')
if len(str) > 0:
    print('文字列のサイズは0以上')
# Out:
# 0以上
# 文字列のサイズは0以上

# %%
if num < 0:
    print('ここは表示されないはず')
elif num > 0:
    print('ハロー！')
else:
    print('ここは表示されないはず')
# Out:
# ハロー！

# %% [markdown]
# ## while文

# %%
while_text = 'spam'
while while_text:
    print(while_text)
    while_text = while_text[1:]
# Out:
# spam
# pam
# am
# m

# %% [markdown]
# ## for文

# %%
for_list = ["hello","world","!!"]
for item in for_list:
    print(item)
# Out:
# hello
# world
# !!
